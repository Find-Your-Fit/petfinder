# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/train.csv")

# %%
df.head()
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72

# %%
train_pos_class = pd.read_csv("C:\github\petfinder\Yet-Another-EfficientDet-Pytorch\dataset\df_pos_class.csv")

# %%
train_pos_class.head()
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity  \
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72
#
#                   points  classes
# 0  [(156, 25, 719, 646)]  ['dog']
# ...

# %%
train_pos_class[["points","classes"]].isna().sum()
# Out:
# points     9911
# classes    9911
# dtype: int64
